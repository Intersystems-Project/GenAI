# %%
# This is a visualisation utilising plotly library with dash so like a web app
# more interactive than matlib and pandasai (can hover over graph and see info breakdown)
# still have not been tested with larger database

# %%
# !pip install "notebook>=5.3" "ipywidgets>=7.5"
# !pip install plotly==5.22.0
# !pip install dash
# !pip install chart_studio
# Out:
# Requirement already satisfied: notebook>=5.3 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (7.0.8)
# Requirement already satisfied: ipywidgets>=7.5 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (8.1.3)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from notebook>=5.3) (2.10.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.22.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from notebook>=5.3) (2.25.1)
# Requirement already satisfied: jupyterlab<4.1,>=4.0.2 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from notebook>=5.3) (4.0.11)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from notebook>=5.3) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from notebook>=5.3) (6.3.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipywidgets>=7.5) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipywidgets>=7.5) (8.20.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipywidgets>=7.5) (5.7.1)
# Requirement already satisfied: widgetsnbextension~=4.0.11 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipywidgets>=7.5) (4.0.11)
# Requirement already satisfied: jupyterlab-widgets~=3.0.11 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipywidgets>=7.5) (3.0.11)
# Requirement already satisfied: decorator in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (0.18.1)
# Requirement already satisfied: matplotlib-inline in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (0.1.6)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (0.2.0)
# Requirement already satisfied: colorama in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipython>=6.1.0->ipywidgets>=7.5) (0.4.6)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (4.2.0)
# Requirement already satisfied: argon2-cffi in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (3.1.3)
# Requirement already satisfied: jupyter-client>=7.4.4 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (5.5.0)
# Requirement already satisfied: jupyter-events>=0.6.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (0.8.0)
# Requirement already satisfied: jupyter-server-terminals in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (7.10.0)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (5.9.2)
# Requirement already satisfied: overrides in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (7.4.0)
# Requirement already satisfied: packaging in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (23.2)
# Requirement already satisfied: prometheus-client in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (0.14.1)
# Requirement already satisfied: pywinpty in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (2.0.10)
# Requirement already satisfied: pyzmq>=24 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (0.17.1)
# Requirement already satisfied: websocket-client in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook>=5.3) (0.58.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=5.3) (2.0.4)
# Requirement already satisfied: ipykernel in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=5.3) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyterlab<4.1,>=4.0.2->notebook>=5.3) (2.2.0)
# Requirement already satisfied: babel>=2.10 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=5.3) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=5.3) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=5.3) (4.19.2)
# Requirement already satisfied: requests>=2.31 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyterlab-server<3,>=2.22.1->notebook>=5.3) (2.31.0)
# Requirement already satisfied: idna>=2.8 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (3.4)
# Requirement already satisfied: sniffio>=1.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.3.0)
# Requirement already satisfied: pytz>=2015.7 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from babel>=2.10->jupyterlab-server<3,>=2.22.1->notebook>=5.3) (2023.3.post1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=7.5) (0.8.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jinja2->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.1.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5.3) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5.3) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5.3) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.22.1->notebook>=5.3) (0.10.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.8.2)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=5.3) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook>=5.3) (305.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.0.7)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (6.0.1)
# Requirement already satisfied: rfc3339-validator in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (4.1.0)
# Requirement already satisfied: defusedxml in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.2.1)
# Requirement already satisfied: fastjsonschema in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.16.2)
# Requirement already satisfied: wcwidth in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets>=7.5) (0.2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=5.3) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=5.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.22.1->notebook>=5.3) (2024.2.2)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=5.3) (21.2.0)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=5.3) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=5.3) (1.6.0)
# Requirement already satisfied: psutil in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from ipykernel->jupyterlab<4.1,>=4.0.2->notebook>=5.3) (5.9.0)
# Requirement already satisfied: executing in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.5) (0.2.2)
# Requirement already satisfied: six in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from websocket-client->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (0.5.1)
# Requirement already satisfied: fqdn in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.1)
# Requirement already satisfied: uri-template in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (24.6.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.5)
# Requirement already satisfied: pycparser in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=2.4.0->notebook>=5.3) (2.21)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.6.0->jupyter-server<3,>=2.4.0->notebook>=5.3) (1.2.3)
# Requirement already satisfied: plotly==5.22.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (5.22.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from plotly==5.22.0) (8.2.2)
# Requirement already satisfied: packaging in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from plotly==5.22.0) (23.2)
# Requirement already satisfied: dash in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (2.17.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (2.2.5)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (2.2.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (5.22.0)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (4.9.0)
# Requirement already satisfied: requests in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (2.31.0)
# Requirement already satisfied: retrying in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from dash) (68.2.2)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.0.1)
# Requirement already satisfied: click>=8.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (8.2.2)
# Requirement already satisfied: packaging in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from plotly>=5.0.0->dash) (23.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from Werkzeug<3.1->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests->dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests->dash) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests->dash) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests->dash) (2024.2.2)
# Requirement already satisfied: six>=1.7.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: colorama in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from click>=8.0->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Collecting chart_studio
#   Downloading chart_studio-1.1.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: plotly in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from chart_studio) (5.22.0)
# Requirement already satisfied: requests in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from chart_studio) (2.31.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from chart_studio) (1.3.4)
# Requirement already satisfied: six in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from chart_studio) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from plotly->chart_studio) (8.2.2)
# Requirement already satisfied: packaging in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from plotly->chart_studio) (23.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests->chart_studio) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests->chart_studio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests->chart_studio) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\joyliu\appdata\local\anaconda3\lib\site-packages (from requests->chart_studio) (2024.2.2)
# Downloading chart_studio-1.1.0-py3-none-any.whl (64 kB)
#    ---------------------------------------- 0.0/64.4 kB ? eta -:--:--
#    ------------------------- -------------- 41.0/64.4 kB 960.0 kB/s eta 0:00:01
#    ---------------------------------------- 64.4/64.4 kB 1.2 MB/s eta 0:00:00
# Installing collected packages: chart_studio
# Successfully installed chart_studio-1.1.0

# %%
import os
import pandas as pd
from pandasai import Agent
import dash
from dash import dcc
from dash import html 
from dash.dependencies import Input, Output
import plotly.express as px
import cohere

# By default, unless you choose a different LLM, it will use BambooLLM.
# You can get your free API key signing up at https://pandabi.ai (you can also configure it in your .env file)
os.environ["PANDASAI_API_KEY"] = ""

# %%
username = ''
password = ''
hostname = os.getenv('IRIS_HOSTNAME', 'localhost')
port = '1972'
namespace = ''
CONNECTION_STRING = f"iris://{username}:{password}@{hostname}:{port}/{namespace}"
print(CONNECTION_STRING)
# Out:
# iris://:@localhost:1972/

# %%
# https://community.intersystems.com/post/langchain-fixed-sql-me
# https://community.intersystems.com/post/using-sqlalchemy-transfer-tables-and-iris
import sqlalchemy as db

engine = db.create_engine(" ")
connection = engine.connect()

# %%
# Read the CSV file
# ONLY NEED TO DO ONCE subsequent runs dont need since tables are loaded already
csv_file_path = 'disease_data.csv'
df = pd.read_csv(csv_file_path)

# Transfer data to IRIS
df.to_sql('Location', engine, if_exists='replace', index=False)

print("Data has been successfully transferred to the IRIS database.")

# %%
# Read the CSV file
csv_file_path = 'Disease_symptom_and_patient_profile_dataset.csv'
df = pd.read_csv(csv_file_path)
# Transfer data to IRIS also only need to be done ONCE (dont need to rerun after it has been done the first time)
df.to_sql('DiseaseProfile', engine, if_exists='replace', index=False)

# %%
# Read the 'DiseaseProfile' table from the SQL database into a DataFrame
DiseaseProfile = pd.read_sql_table('DiseaseProfile', connection, schema="SQLUser")

# %%
DiseaseProfile.head(5)
# Out:
#        Disease Fever Cough Fatigue Difficulty_Breathing  Age  Gender  \
# 0    Influenza   Yes    No     Yes                  Yes   19  Female
# 1  Common Cold    No   Yes     Yes                   No   25  Female
# 2       Eczema    No   Yes     Yes                   No   25  Female
# 3       Asthma   Yes   Yes      No                  Yes   25    Male
# 4       Asthma   Yes   Yes      No                  Yes   25    Male
#
#   Blood_Pressure Cholesterol_Level Outcome_Variable
# 0            Low            Normal         Positive
# 1         Normal            Normal         Negative
# 2         Normal            Normal         Negative
# 3         Normal            Normal         Positive
# 4         Normal            Normal         Positive

# %%
from pandasai import SmartDataframe

from langchain_cohere import ChatCohere


# llm = BambooLLM(api_key="$2a$10$GfFQiPXypOZBsp.EXT3J7.vCbxMJqVd1rlsoJPjB/A5B9olozt0Di")
# smart_df = SmartDataframe(DiseaseProfile, name="DiseaseProfile", description="Dataset used to generate SQL query")
# smart_df = SmartDataframe(DiseaseProfile, name="DiseaseProfile", description="Dataset used to generate SQL query", config={"llm": llm})

cohere_api_key = ""
# os.environ.get('COHERE_API_KEY_TWO')

# https://docs.cohere.com/docs/models
model = "command"

temperature = 0
llm = ChatCohere(model=model,temperature=0, cohere_api_key=cohere_api_key)
smart_df = SmartDataframe(DiseaseProfile, name="DiseaseProfile", description="Dataset used to generate SQL query", config={"llm": llm})

# %%
# https://community.intersystems.com/post/langchain-fixed-sql-me
from langchain.sql_database import SQLDatabase
from langchain_experimental.sql import SQLDatabaseChain
from langchain.prompts.prompt import PromptTemplate

_DEFAULT_TEMPLATE = """Given an input question, first create a syntactically correct {dialect} query to run, then look at the results of the query and return the answer.

The only table available is DiseaseProfile.

The columns are Disease VARCHAR(512), Fever VARCHAR(25), Cough VARCHAR(25), Fatigue VARCHAR(25), Difficulty_Breathing VARCHAR(25), Age INT, Gender VARCHAR(25), Blood_Pressure VARCHAR(25), Cholesterol_Level VARCHAR(25), Outcome_Variable VARCHAR(25).
Fever, Cough, Fatigue and DifficultyBreathing are potential symptoms which the patients are experiencing. 

Columns and Usage:

Disease: The name of the disease or medical condition.
Fever: Indicates whether the patient has a fever (Yes/No).
Cough: Indicates whether the patient has a cough (Yes/No).
Fatigue: Indicates whether the patient experiences fatigue (Yes/No).
Difficulty_Breathing: Indicates whether the patient has difficulty breathing (Yes/No).
Age: The age of the patient in years.
Gender: The gender of the patient (Male/Female).
Blood_Pressure: The blood pressure level of the patient (Normal/High).
Cholesterol_Level: The cholesterol level of the patient (Normal/High).
Outcome_Variable: The outcome variable indicating the result of the diagnosis or assessment for the specific disease (Positive/Negative).

Use the following format:

Question: "Question here"
SQLQuery: "SQL Query to run"
SQLResult: "Result of the SQLQuery"
Answer: "Final answer here"

The SQL query should NOT end with semi-colon
Question: {input}"""

PROMPT = PromptTemplate(
    input_variables=["input", "dialect"], template=_DEFAULT_TEMPLATE
)

db_sql = SQLDatabase.from_uri(CONNECTION_STRING) 

db_chain = SQLDatabaseChain.from_llm(llm=llm, db=db_sql, return_direct=True, return_intermediate_steps=True, prompt=PROMPT, verbose=True)

# %%
# dash web app 
# hosted on port 8053
# image of graph can be downloaded as a png by clicking the camera icon
# Import necessary libraries
import pandas as pd
from dash import Dash, html, dcc, dash_table, Input, Output, callback
from jupyter_dash import JupyterDash
import plotly.express as px
import cohere
#from pandasai import SmartDataframe
from cohere import ClassifyExample

# Load the data either from IRIS of from same directory
#csv_file_path = 'disease_data.csv'
df = pd.read_sql_table('Location', connection, schema="SQLUser")

# Initialize the Cohere API
cohere_api_key = "mD1SGFkiLf0RlAzUBJGn7uIPbdK95sCp2ys1eGWL"
co = cohere.Client(cohere_api_key)
examples=[
            ClassifyExample(text="Plot a bar chart for the top 5 diseases by count", label="bar"),
            ClassifyExample(text="Show me a histogram of ages", label="histogram"),
            ClassifyExample(text="Create a box plot of disease counts", label="box"),
            ClassifyExample(text="Display a pie chart of disease distribution", label="pie")
        ]
def generate_visualization(query):
    response = co.classify(
        model='large',
        inputs=[query],
        examples=[
            ClassifyExample(text="Plot a bar chart for the top 5 diseases by count", label="bar"),
            ClassifyExample(text="Show me a histogram of ages", label="histogram"),
            ClassifyExample(text="Create a box plot of disease counts", label="box"),
            ClassifyExample(text="Display a pie chart of disease distribution", label="pie"),
            ClassifyExample(text="I want a bar chart for the most common diseases", label="bar"),
            ClassifyExample(text="Give me a histogram of patient ages", label="histogram"),
            ClassifyExample(text="Make a box plot of the number of diseases", label="box"),
            ClassifyExample(text="Can you show a pie chart of how diseases are distributed?", label="pie"),
            ClassifyExample(text="Show a bar graph of disease occurrences", label="bar"),
            ClassifyExample(text="I need a histogram of age distribution", label="histogram"),
            ClassifyExample(text="Box plot the counts of different diseases", label="box"),
            ClassifyExample(text="Pie chart of disease counts", label="pie")
        ]
    )
    chart_type = response.classifications[0].prediction
    return chart_type

# Initialize the Dash app
app = Dash(__name__)

# App layout
app.layout = html.Div([
    html.H1('Disease Data Visualization', style={'textAlign': 'center'}),
    html.Hr(),
    dash_table.DataTable(
        data=df.to_dict('records'),
        page_size=6,
        style_table={'height': '300px', 'overflowY': 'auto'}
    ),
    dcc.Input(id='nl-query', type='text', value='', style={'width': '100%'}),
    html.Button('Submit', id='submit-query', n_clicks=0),
    dcc.Graph(id='visualization')
])

# Add callback to update graph based on natural language query
@app.callback(
    Output('visualization', 'figure'),
    [Input('submit-query', 'n_clicks')],
    [Input('nl-query', 'value')]
)
def update_graph(n_clicks, nl_query):
    if n_clicks > 0 and nl_query:
        chart_type = generate_visualization(nl_query)
        if chart_type == "bar":
            fig = px.bar(df, x='Disease', y='Count')
        elif chart_type == "histogram":
            fig = px.histogram(df, x='Disease', y='Count')
        elif chart_type == "box":
            fig = px.box(df, y='Count')
        elif chart_type == "pie":
            fig = px.pie(df, names='Disease', values='Count')
        return fig
    return px.bar(df, x='Disease', y='Count')  # Default chart

# Run the app
if __name__ == '__main__':
    app.run(debug=True, port=8053)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8053/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
